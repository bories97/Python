# %%
import pandas as pd
import numpy as np

# %%
soccer_info = pd.read_csv('C:/Users/USER/Desktop/프로젝트 관련/공모전 데이터/raw_data.csv')
match_info = pd.read_csv('C:/Users/USER/Desktop/프로젝트 관련/공모전 데이터/match_info.csv')

# %%
match_info_fix = match_info.drop(columns=["season_id",
                                          "competition_id",
                                          "competition_name",
                                          "country_name",
                                          "home_team_name",
                                          "season_name",
                                          "away_team_name"])

# %%
soccer_df = soccer_info.merge(match_info_fix, on='game_id', how = 'left')

# %%
soccer_df
# Out:
#         game_id  action_id  period_id  time_seconds  team_id  player_id  \
# 0        126288          0          1         1.033     2353   356625.0
# 1        126288          1          1         2.433     2353   356612.0
# 2        126288          2          1         3.033     2353   356612.0
# 3        126288          3          1         4.333     2353   356618.0
# 4        126288          4          1         4.900     2353   356618.0
# ...         ...        ...        ...           ...      ...        ...
# 579301   126291       3099          2      3186.533     2354   187292.0
# 579302   126291       3100          2      3187.667     2354   500143.0
# 579303   126291       3101          2      3187.668     2354   500143.0
# 579304   126291       3102          2      3189.467     2354   500143.0
# 579305   126291       3103          2      3191.333     2353   356614.0
#
#          result_name    start_x    start_y      end_x  ...  main_position  \
# 0         Successful  52.670205  34.919632  68.628945  ...             CF
# 1                NaN  68.628945  34.347412  68.628945  ...             CM
# 2         Successful  68.228055  33.853256  65.468865  ...             CM
# 3                NaN  65.468865  26.640292  65.468865  ...             CM
# 4         Successful  64.838025  26.766636  63.300510  ...             CM
# ...              ...        ...        ...        ...  ...            ...
# 579301    Successful   8.762670   2.118390   5.423670  ...             CF
# 579302           NaN   5.423670   2.112168   5.423670  ...             LB
# 579303           NaN   5.423670   2.112168   1.041810  ...             LB
# 579304  Unsuccessful   1.041810   9.064876   7.936215  ...             LB
# 579305           NaN   7.754229  40.507872   7.754229  ...             RB
#
#         game_day            game_date home_team_id away_team_id home_score  \
# 0              1  2024-03-03 05:00:00         4644         2353          0
# 1              1  2024-03-03 05:00:00         4644         2353          0
# 2              1  2024-03-03 05:00:00         4644         2353          0
# 3              1  2024-03-03 05:00:00         4644         2353          0
# 4              1  2024-03-03 05:00:00         4644         2353          0
# ...          ...                  ...          ...          ...        ...
# 579301         2  2024-03-09 07:30:00         2353         2354          2
# 579302         2  2024-03-09 07:30:00         2353         2354          2
# 579303         2  2024-03-09 07:30:00         2353         2354          2
# 579304         2  2024-03-09 07:30:00         2353         2354          2
# 579305         2  2024-03-09 07:30:00         2353         2354          2
#
#        away_score      venue  home_team_name_ko away_team_name_ko
# 0               1  DGB대구은행파크               대구FC       김천 상무 프로축구단
# 1               1  DGB대구은행파크               대구FC       김천 상무 프로축구단
# 2               1  DGB대구은행파크               대구FC       김천 상무 프로축구단
# 3               1  DGB대구은행파크               대구FC       김천 상무 프로축구단
# 4               1  DGB대구은행파크               대구FC       김천 상무 프로축구단
# ...           ...        ...                ...               ...
# 579301          3    김천종합운동장        김천 상무 프로축구단          울산 HD FC
# 579302          3    김천종합운동장        김천 상무 프로축구단          울산 HD FC
# 579303          3    김천종합운동장        김천 상무 프로축구단          울산 HD FC
# 579304          3    김천종합운동장        김천 상무 프로축구단          울산 HD FC
# 579305          3    김천종합운동장        김천 상무 프로축구단          울산 HD FC
#
# [579306 rows x 27 columns]
