# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.random.randint(1, 3000, (500, 3)), columns=['a','b','c'])

# %%
df
# Out:
#         a     b     c
# 0     169  2024  1999
# 1    1724  1122   321
# 2    2579  1344  2655
# 3     161  2426   641
# 4     623  1358   622
# ..    ...   ...   ...
# 495  1442   621  2308
# 496  1158  1797  1118
# 497   693  2580  2892
# 498   973  1532   236
# 499  2296   306  2816
#
# [500 rows x 3 columns]

# %%
df_smooth = df.rolling(window=10).mean()

# %%
plt.figure(figsize=(15,5))
plt.plot(df_smooth)
plt.legend(df.columns)
plt.show()
