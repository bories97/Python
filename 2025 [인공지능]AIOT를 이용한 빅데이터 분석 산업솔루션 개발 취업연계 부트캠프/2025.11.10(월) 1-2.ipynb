# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dict_data = {'a':1, 'b':2, 'c':3}

# %%
sr = pd.Series(dict_data)

# %%
sr
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
type(sr)
# Out:
# pandas.core.series.Series

# %%
# list로 시리즈 만들기

# %%
list_data = ['2019-01-02', 3.14, 'ABC', 100, True]
list_data
# Out:
# ['2019-01-02', 3.14, 'ABC', 100, True]

# %%
sr = pd.Series(list_data)

# %%
sr
# Out:
# 0    2019-01-02
# 1          3.14
# 2           ABC
# 3           100
# 4          True
# dtype: object

# %%
# 인덱스 및 값 구조

# %%
list(range(0, 11, 1))[::2]
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
sr.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
sr.values
# Out:
# array(['2019-01-02', 3.14, 'ABC', 100, True], dtype=object)

# %%
idx = sr.index
val = sr.values
print(idx)
print(val)
# Out:
# RangeIndex(start=0, stop=5, step=1)
# ['2019-01-02' 3.14 'ABC' 100 True]

# %%
idx
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
val
# Out:
# array(['2019-01-02', 3.14, 'ABC', 100, True], dtype=object)

# %% [markdown]
# 튜플로 시리즈 만들기

# %%
tup_data = ('영인', '2010-05-01', '여', True)
tup_data
# Out:
# ('영인', '2010-05-01', '여', True)

# %%
sr = pd.Series(tup_data, index=['이름', '생년월일', '성별', '내국인 여부'])

# %%
sr
# Out:
# 이름                영인
# 생년월일      2010-05-01
# 성별                 여
# 내국인 여부          True
# dtype: object

# %%
# 시리즈 데이터 원소 추출

# %%
print(sr['이름'])
# Out:
# 영인

# %%
sr['이름':'생년월일']
# Out:
# 이름              영인
# 생년월일    2010-05-01
# dtype: object

# %%
sr['생년월일':'이름'] #데이터 순서대로 슬라이싱 해야함 다르게 하면 오류난다
# Out:
# Series([], dtype: object)

# %%
print(sr[0:3])
# Out:
# 이름              영인
# 생년월일    2010-05-01
# 성별               여
# dtype: object

# %%
# DataFrame 만들기

# %%
dict_data = {'c0':[1,2,3], 'c1':[4,5,6], 'c2':[7,8,9], 'c4':[10, 11, 12]}
df =pd.DataFrame(dict_data)
