# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    '이름' : ['김', '이', '박'],
    '나이' : [28, 27, 30],
    '지역' : ['서울' , '부산', '대구']
})

# %%
df
# Out:
#   이름  나이  지역
# 0  김  28  서울
# 1  이  27  부산
# 2  박  30  대구

# %%
df.loc[df['나이'] >= 28, '상태'] = '일반인'

# %%
df.loc[df['나이'] <= 28, '상태'] = '학생'

# %%
import folium 
import json

# %%
people2026 = pd.read_excel('C:/Users/USER/Desktop/연습데이터/2024년_인구데이터.xlsx', skiprows=1)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
people2026.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741 entries, 0 to 740
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   행정구역(시군구)별(1)  18 non-null     object
#  1   행정구역(시군구)별(2)  247 non-null    object
#  2   성별(1)          741 non-null    object
#  3   계              741 non-null    float64
#  4   20 - 24세       741 non-null    float64
#  5   25 - 29세       741 non-null    float64
#  6   30 - 34세       741 non-null    float64
#  7   35 - 39세       741 non-null    float64
#  8   40 - 44세       741 non-null    float64
#  9   45 - 49세       741 non-null    float64
#  10  50 - 54세       741 non-null    float64
#  11  55 - 59세       741 non-null    float64
#  12  60 - 64세       741 non-null    float64
#  13  65 - 69세       741 non-null    float64
#  14  70 - 74세       741 non-null    float64
#  15  75 - 79세       741 non-null    float64
#  16  80세 이상         741 non-null    float64
# ...

# %%
people2026_1 = people2026

# %%
people2026_1.head()
# Out:
#   행정구역(시군구)별(1) 행정구역(시군구)별(2) 성별(1)           계   20 - 24세   25 - 29세  \
# 0            전국            소계     계  51037252.5  2715177.5  3345302.5
# 1           NaN           NaN    남자  25400503.0  1410684.5  1749087.0
# 2           NaN           NaN    여자  25636749.5  1304493.0  1596215.5
# 3         서울특별시            소계     계   9288119.0   540958.0   786238.0
# 4           NaN           NaN    남자   4486066.5   253312.5   373857.0
#
#     30 - 34세   35 - 39세   40 - 44세   45 - 49세  ...   65 - 69세   70 - 74세  \
# 0  3426128.0  3145432.0  3942230.0  3830094.0  ...  3502182.0  2324531.5
# 1  1802576.0  1620174.0  2005710.0  1942249.5  ...  1703153.0  1092697.0
# 2  1623552.0  1525258.0  1936520.0  1887844.5  ...  1799029.0  1231834.5
# 3   783490.5   643327.5   716405.0   671810.5  ...   615615.5   423867.0
# 4   393071.0   320819.5   355381.0   330694.0  ...   286904.5   194370.5
#
#     75 - 79세     80세 이상   80 - 84세     85세 이상  85 - 89세  90 - 94세  95 - 99세  \
# ...

# %%
people2026_1 = people2026_1.rename(columns={'행정구역(시군구)별(1)': '광역시도', '행정구역(시군구)별(2)': '시도',
                                   '성별(1)':'구분', '계':'인구수', '100세 이상':'100+'})

# %%
people2026_1.head()
# Out:
#     광역시도   시도  구분         인구수   20 - 24세   25 - 29세   30 - 34세   35 - 39세  \
# 0     전국   소계   계  51037252.5  2715177.5  3345302.5  3426128.0  3145432.0
# 1    NaN  NaN  남자  25400503.0  1410684.5  1749087.0  1802576.0  1620174.0
# 2    NaN  NaN  여자  25636749.5  1304493.0  1596215.5  1623552.0  1525258.0
# 3  서울특별시   소계   계   9288119.0   540958.0   786238.0   783490.5   643327.5
# 4    NaN  NaN  남자   4486066.5   253312.5   373857.0   393071.0   320819.5
#
#     40 - 44세   45 - 49세  ...   65 - 69세   70 - 74세   75 - 79세     80세 이상  \
# 0  3942230.0  3830094.0  ...  3502182.0  2324531.5  1737959.0  2390803.5
# 1  2005710.0  1942249.5  ...  1703153.0  1092697.0   776189.5   834606.0
# 2  1936520.0  1887844.5  ...  1799029.0  1231834.5   961769.5  1556197.5
# 3   716405.0   671810.5  ...   615615.5   423867.0   327072.5   393408.0
# 4   355381.0   330694.0  ...   286904.5   194370.5   145187.0   152627.5
#
#     80 - 84세     85세 이상  85 - 89세  90 - 94세  95 - 99세    100+
# ...

# %%
people2026_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741 entries, 0 to 740
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   광역시도      18 non-null     object
#  1   시도        247 non-null    object
#  2   구분        741 non-null    object
#  3   인구수       741 non-null    float64
#  4   20 - 24세  741 non-null    float64
#  5   25 - 29세  741 non-null    float64
#  6   30 - 34세  741 non-null    float64
#  7   35 - 39세  741 non-null    float64
#  8   40 - 44세  741 non-null    float64
#  9   45 - 49세  741 non-null    float64
#  10  50 - 54세  741 non-null    float64
#  11  55 - 59세  741 non-null    float64
#  12  60 - 64세  741 non-null    float64
#  13  65 - 69세  741 non-null    float64
#  14  70 - 74세  741 non-null    float64
#  15  75 - 79세  741 non-null    float64
#  16  80세 이상    741 non-null    float64
#  17  80 - 84세  741 non-null    float64
#  18  85세 이상    741 non-null    float64
# ...

# %%
people2026_1.loc[people2026_1['구분'] == '계', '구분'] = '합계'

# %%
people2026_1.head()
# Out:
#     광역시도   시도  구분         인구수   20 - 24세   25 - 29세   30 - 34세   35 - 39세  \
# 0     전국   소계  합계  51037252.5  2715177.5  3345302.5  3426128.0  3145432.0
# 1    NaN  NaN  남자  25400503.0  1410684.5  1749087.0  1802576.0  1620174.0
# 2    NaN  NaN  여자  25636749.5  1304493.0  1596215.5  1623552.0  1525258.0
# 3  서울특별시   소계  합계   9288119.0   540958.0   786238.0   783490.5   643327.5
# 4    NaN  NaN  남자   4486066.5   253312.5   373857.0   393071.0   320819.5
#
#     40 - 44세   45 - 49세  ...   65 - 69세   70 - 74세   75 - 79세     80세 이상  \
# 0  3942230.0  3830094.0  ...  3502182.0  2324531.5  1737959.0  2390803.5
# 1  2005710.0  1942249.5  ...  1703153.0  1092697.0   776189.5   834606.0
# 2  1936520.0  1887844.5  ...  1799029.0  1231834.5   961769.5  1556197.5
# 3   716405.0   671810.5  ...   615615.5   423867.0   327072.5   393408.0
# 4   355381.0   330694.0  ...   286904.5   194370.5   145187.0   152627.5
#
#     80 - 84세     85세 이상  85 - 89세  90 - 94세  95 - 99세    100+
# ...

# %%
people2026_1.fillna(method='ffill', inplace = True)

# %%
people2026_1.head(7)
# Out:
#     광역시도   시도  구분         인구수   20 - 24세   25 - 29세   30 - 34세   35 - 39세  \
# 0     전국   소계  합계  51037252.5  2715177.5  3345302.5  3426128.0  3145432.0
# 1     전국   소계  남자  25400503.0  1410684.5  1749087.0  1802576.0  1620174.0
# 2     전국   소계  여자  25636749.5  1304493.0  1596215.5  1623552.0  1525258.0
# 3  서울특별시   소계  합계   9288119.0   540958.0   786238.0   783490.5   643327.5
# 4  서울특별시   소계  남자   4486066.5   253312.5   373857.0   393071.0   320819.5
# 5  서울특별시   소계  여자   4802052.5   287645.5   412381.0   390419.5   322508.0
# 6  서울특별시  종로구  합계    137094.5     8827.0    12277.0    11024.0     8350.5
#
#     40 - 44세   45 - 49세  ...   65 - 69세   70 - 74세   75 - 79세     80세 이상  \
# 0  3942230.0  3830094.0  ...  3502182.0  2324531.5  1737959.0  2390803.5
# 1  2005710.0  1942249.5  ...  1703153.0  1092697.0   776189.5   834606.0
# 2  1936520.0  1887844.5  ...  1799029.0  1231834.5   961769.5  1556197.5
# 3   716405.0   671810.5  ...   615615.5   423867.0   327072.5   393408.0
# ...

# %%
people2026_1['20-39세'] = people2026_1['20 - 24세'] + people2026_1['25 - 29세'] + \
                          people2026_1['30 - 34세'] + people2026_1['35 - 39세']

# %%
people2026_1['65세이상'] = people2026_1['65 - 69세'] + people2026_1['70 - 74세'] + \
                          people2026_1['75 - 79세'] + people2026_1['80 - 84세'] + \
                          people2026_1['85 - 89세'] + people2026_1['90 - 94세'] + people2026_1['100+']

# %%
people2026_1.head()
# Out:
#     광역시도  시도  구분         인구수   20 - 24세   25 - 29세   30 - 34세   35 - 39세  \
# 0     전국  소계  합계  51037252.5  2715177.5  3345302.5  3426128.0  3145432.0
# 1     전국  소계  남자  25400503.0  1410684.5  1749087.0  1802576.0  1620174.0
# 2     전국  소계  여자  25636749.5  1304493.0  1596215.5  1623552.0  1525258.0
# 3  서울특별시  소계  합계   9288119.0   540958.0   786238.0   783490.5   643327.5
# 4  서울특별시  소계  남자   4486066.5   253312.5   373857.0   393071.0   320819.5
#
#     40 - 44세   45 - 49세  ...   75 - 79세     80세 이상   80 - 84세     85세 이상  \
# 0  3942230.0  3830094.0  ...  1737959.0  2390803.5  1332256.5  1058547.0
# 1  2005710.0  1942249.5  ...   776189.5   834606.0   521935.0   312671.0
# 2  1936520.0  1887844.5  ...   961769.5  1556197.5   810321.5   745876.0
# 3   716405.0   671810.5  ...   327072.5   393408.0   230572.0   162836.0
# 4   355381.0   330694.0  ...   145187.0   152627.5    97849.0    54778.5
#
#    85 - 89세  90 - 94세  95 - 99세    100+      20-39세      65세이상
# ...

# %%
people2026_1.columns
# Out:
# Index(['광역시도', '시도', '구분', '인구수', '20 - 24세', '25 - 29세', '30 - 34세',
#        '35 - 39세', '40 - 44세', '45 - 49세', '50 - 54세', '55 - 59세', '60 - 64세',
#        '65 - 69세', '70 - 74세', '75 - 79세', '80세 이상', '80 - 84세', '85세 이상',
#        '85 - 89세', '90 - 94세', '95 - 99세', '100+', '20-39세', '65세이상'],
#       dtype='object')

# %%
people2026_1.drop(['40 - 44세', '45 - 49세', '50 - 54세',
                   '55 - 59세', '60 - 64세', '80세 이상', '85세 이상'], axis=1, inplace=True)

# %%
people2026_1.head()
# Out:
#     광역시도  시도  구분         인구수   20 - 24세   25 - 29세   30 - 34세   35 - 39세  \
# 0     전국  소계  합계  51037252.5  2715177.5  3345302.5  3426128.0  3145432.0
# 1     전국  소계  남자  25400503.0  1410684.5  1749087.0  1802576.0  1620174.0
# 2     전국  소계  여자  25636749.5  1304493.0  1596215.5  1623552.0  1525258.0
# 3  서울특별시  소계  합계   9288119.0   540958.0   786238.0   783490.5   643327.5
# 4  서울특별시  소계  남자   4486066.5   253312.5   373857.0   393071.0   320819.5
#
#     65 - 69세   70 - 74세   75 - 79세   80 - 84세  85 - 89세  90 - 94세  95 - 99세  \
# 0  3502182.0  2324531.5  1737959.0  1332256.5  737135.5  257365.5   55929.0
# 1  1703153.0  1092697.0   776189.5   521935.0  238765.5   62485.0   10087.0
# 2  1799029.0  1231834.5   961769.5   810321.5  498370.0  194880.5   45842.0
# 3   615615.5   423867.0   327072.5   230572.0  114558.5   38085.5    8865.0
# 4   286904.5   194370.5   145187.0    97849.0   41851.5   10696.5    1948.0
#
#      100+      20-39세      65세이상
# 0  8117.0  12632040.0  9899547.0
# ...

# %%
people2026_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741 entries, 0 to 740
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   광역시도      741 non-null    object
#  1   시도        741 non-null    object
#  2   구분        741 non-null    object
#  3   인구수       741 non-null    float64
#  4   20 - 24세  741 non-null    float64
#  5   25 - 29세  741 non-null    float64
#  6   30 - 34세  741 non-null    float64
#  7   35 - 39세  741 non-null    float64
#  8   65 - 69세  741 non-null    float64
#  9   70 - 74세  741 non-null    float64
#  10  75 - 79세  741 non-null    float64
#  11  80 - 84세  741 non-null    float64
#  12  85 - 89세  741 non-null    float64
#  13  90 - 94세  741 non-null    float64
#  14  95 - 99세  741 non-null    float64
#  15  100+      741 non-null    float64
#  16  20-39세    741 non-null    float64
#  17  65세이상     741 non-null    float64
# dtypes: float64(15), object(3)
# memory usage: 104.3+ KB

# %%
popl = pd.pivot_table(people2026_1, index=['광역시도', '시도'], columns='구분',
                      values=['인구수', '20-39세', '65세이상'])

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', '{:,.0f}'.format)

# %%
popl
# Out:
#                    20-39세                          65세이상                      \
# 구분                     남자        여자         합계        남자        여자        합계
# 광역시도    시도
# 강원특별자치도 강릉시        22,929    19,342     42,271    22,833    29,660    52,494
#         고성군         2,829     1,955      4,784     3,912     4,938     8,850
#         동해시         9,370     7,067     16,438     9,356    11,854    21,210
#         삼척시         6,306     5,004     11,310     7,976    10,248    18,224
#         소계        173,762   143,714    317,476   166,736   205,557   372,294
#         속초시         9,253     7,392     16,646     8,208    10,547    18,756
#         양구군         2,773     1,816      4,588     2,462     2,878     5,341
#         양양군         2,372     1,710      4,082     4,306     5,145     9,452
#         영월군         2,790     2,216      5,006     5,971     6,843    12,814
#         원주시        45,410    41,556     86,966    29,436    36,646    66,082
# ...

# %%
popl[('20-39세','여자')]
# Out:
# 광역시도     시도
# 강원특별자치도  강릉시          19,342
#          고성군           1,955
#          동해시           7,067
#          삼척시           5,004
#          소계          143,714
#          속초시           7,392
#          양구군           1,816
#          양양군           1,710
#          영월군           2,216
#          원주시          41,556
#          인제군           2,767
#          정선군           1,880
#          철원군           3,384
#          춘천시          33,480
#          태백시           2,478
#          평창군           2,343
#          홍천군           4,658
#          화천군           1,990
#          횡성군           2,675
# 경기도      가평군           4,828
#          고양시         136,549
#          과천시          11,076
#          광명시          33,682
#          광주시          44,172
#          구리시          23,034
#          군포시          32,011
#          김포시          56,922
#          남양주시         81,175
#          동두천시          8,254
#          부천시          97,530
#          성남시         120,576
# ...

# %%
popl['소멸비율'] = popl[('20-39세','여자')] / popl[('65세이상', '합계')]

# %%
pd.reset_option('display.float_format')

# %%
popl
# Out:
#                     20-39세                             65세이상             \
# 구분                      남자         여자          합계         남자         여자
# 광역시도    시도
# 강원특별자치도 강릉시        22929.0    19342.0     42271.0    22833.0    29660.5
#         고성군         2829.0     1955.0      4784.0     3912.5     4938.0
#         동해시         9370.5     7067.0     16437.5     9356.0    11853.5
#         삼척시         6306.0     5004.5     11310.5     7975.5    10248.5
#         소계        173762.0   143713.5    317475.5   166736.5   205557.0
#         속초시         9253.0     7392.5     16645.5     8208.5    10547.0
#         양구군         2773.0     1815.5      4588.5     2462.5     2878.5
#         양양군         2372.5     1709.5      4082.0     4306.5     5145.0
#         영월군         2790.0     2215.5      5005.5     5971.0     6843.0
#         원주시        45409.5    41556.5     86966.0    29435.5    36646.0
#         인제군         4861.0     2767.0      7628.0     3730.0     4004.0
# ...

# %%
popl['소멸위기지역'] = popl['소멸비율'] < 0.5 
popl.head(10)
# Out:
#                20-39세                         65세이상                      \
# 구분                 남자        여자        합계        남자        여자        합계
# 광역시도    시도
# 강원특별자치도 강릉시   22929.0   19342.0   42271.0   22833.0   29660.5   52493.5
#         고성군    2829.0    1955.0    4784.0    3912.5    4938.0    8850.5
#         동해시    9370.5    7067.0   16437.5    9356.0   11853.5   21209.5
#         삼척시    6306.0    5004.5   11310.5    7975.5   10248.5   18224.0
#         소계   173762.0  143713.5  317475.5  166736.5  205557.0  372293.5
#         속초시    9253.0    7392.5   16645.5    8208.5   10547.0   18755.5
#         양구군    2773.0    1815.5    4588.5    2462.5    2878.5    5341.0
#         양양군    2372.5    1709.5    4082.0    4306.5    5145.0    9451.5
#         영월군    2790.0    2215.5    5005.5    5971.0    6843.0   12814.0
#         원주시   45409.5   41556.5   86966.0   29435.5   36646.0   66081.5
#
#                   인구수                           소멸비율 소멸위기지역
# ...

# %%
popl.reset_index()
# Out:
#         광역시도       시도     20-39세                             65세이상             \
# 구분                            남자         여자          합계         남자         여자
# 0    강원특별자치도      강릉시    22929.0    19342.0     42271.0    22833.0    29660.5
# 1    강원특별자치도      고성군     2829.0     1955.0      4784.0     3912.5     4938.0
# 2    강원특별자치도      동해시     9370.5     7067.0     16437.5     9356.0    11853.5
# 3    강원특별자치도      삼척시     6306.0     5004.5     11310.5     7975.5    10248.5
# 4    강원특별자치도       소계   173762.0   143713.5    317475.5   166736.5   205557.0
# 5    강원특별자치도      속초시     9253.0     7392.5     16645.5     8208.5    10547.0
# 6    강원특별자치도      양구군     2773.0     1815.5      4588.5     2462.5     2878.5
# 7    강원특별자치도      양양군     2372.5     1709.5      4082.0     4306.5     5145.0
# 8    강원특별자치도      영월군     2790.0     2215.5      5005.5     5971.0     6843.0
# 9    강원특별자치도      원주시    45409.5    41556.5     86966.0    29435.5    36646.0
# ...

# %%
popl.reset_index(inplace=True)
popl.head()
# Out:
#        광역시도   시도    20-39세                         65세이상                      \
# 구분                      남자        여자        합계        남자        여자        합계
# 0   강원특별자치도  강릉시   22929.0   19342.0   42271.0   22833.0   29660.5   52493.5
# 1   강원특별자치도  고성군    2829.0    1955.0    4784.0    3912.5    4938.0    8850.5
# 2   강원특별자치도  동해시    9370.5    7067.0   16437.5    9356.0   11853.5   21209.5
# 3   강원특별자치도  삼척시    6306.0    5004.5   11310.5    7975.5   10248.5   18224.0
# 4   강원특별자치도   소계  173762.0  143713.5  317475.5  166736.5  205557.0  372293.5
#
#          인구수                           소멸비율 소멸위기지역
# 구분        남자        여자         합계
# 0   102917.5  104956.5   207874.0  0.368465   True
# 1    13890.0   13189.5    27079.5  0.220891   True
# 2    44582.5   43227.5    87810.0  0.333200   True
# 3    31534.0   30499.5    62033.5  0.274610   True
# 4   762647.0  754712.5  1517359.5  0.386022   True

# %%
popl['시도'].unique()
# Out:
# array(['강릉시', '고성군', '동해시', '삼척시', '소계', '속초시', '양구군', '양양군', '영월군',
#        '원주시', '인제군', '정선군', '철원군', '춘천시', '태백시', '평창군', '홍천군', '화천군',
#        '횡성군', '가평군', '고양시', '과천시', '광명시', '광주시', '구리시', '군포시', '김포시',
#        '남양주시', '동두천시', '부천시', '성남시', '수원시', '시흥시', '안산시', '안성시', '안양시',
#        '양주시', '양평군', '여주시', '연천군', '오산시', '용인시', '의왕시', '의정부시', '이천시',
#        '파주시', '평택시', '포천시', '하남시', '화성시', '거제시', '거창군', '김해시', '남해군',
#        '밀양시', '사천시', '산청군', '양산시', '의령군', '진주시', '창녕군', '창원시', '통영시',
#        '하동군', '함안군', '함양군', '합천군', '경산시', '경주시', '고령군', '구미시', '김천시',
#        '문경시', '봉화군', '상주시', '성주군', '안동시', '영덕군', '영양군', '영주시', '영천시',
#        '예천군', '울릉군', '울진군', '의성군', '청도군', '청송군', '칠곡군', '포항시', '광산구',
#        '남구', '동구', '북구', '서구', '군위군', '달서구', '달성군', '수성구', '중구', '대덕구',
#        '유성구', '강서구', '금정구', '기장군', '동래구', '부산진구', '사상구', '사하구', '수영구',
#        '연제구', '영도구', '해운대구', '강남구', '강동구', '강북구', '관악구', '광진구', '구로구',
# ...

# %%
popl['시도'].str[0:2]
# Out:
# 0      강릉
# 1      고성
# 2      동해
# 3      삼척
# 4      소계
# 5      속초
# 6      양구
# 7      양양
# 8      영월
# 9      원주
# 10     인제
# 11     정선
# 12     철원
# 13     춘천
# 14     태백
# 15     평창
# 16     홍천
# 17     화천
# 18     횡성
# 19     가평
# 20     고양
# 21     과천
# 22     광명
# 23     광주
# 24     구리
# 25     군포
# 26     김포
# 27     남양
# 28     동두
# 29     부천
# 30     성남
# 31     소계
# 32     수원
# 33     시흥
# 34     안산
# 35     안성
# 36     안양
# 37     양주
# 38     양평
# 39     여주
# 40     연천
# 41     오산
# 42     용인
# 43     의왕
# 44     의정
# 45     이천
# 46     파주
# 47     평택
# 48     포천
# 49     하남
# 50     화성
# 51     거제
# 52     거창
# 53     고성
# 54     김해
# 55     남해
# 56     밀양
# 57     사천
# 58     산청
# 59     소계
# 60     양산
# 61     의령
# 62     진주
# 63     창녕
# 64     창원
# 65     통영
# 66     하동
# 67     함안
# 68     함양
# 69     합천
# 70     경산
# 71     경주
# 72     고령
# 73     구미
# 74     김천
# 75     문경
# 76     봉화
# 77     상주
# 78     성주
# 79     소계
# 80     안동
# 81     영덕
# 82     영양
# ...

# %%
popl['id'] = popl['시도'].str[0:2]

# %%
popl.head()
# Out:
#        광역시도   시도    20-39세                         65세이상                      \
# 구분                      남자        여자        합계        남자        여자        합계
# 0   강원특별자치도  강릉시   22929.0   19342.0   42271.0   22833.0   29660.5   52493.5
# 1   강원특별자치도  고성군    2829.0    1955.0    4784.0    3912.5    4938.0    8850.5
# 2   강원특별자치도  동해시    9370.5    7067.0   16437.5    9356.0   11853.5   21209.5
# 3   강원특별자치도  삼척시    6306.0    5004.5   11310.5    7975.5   10248.5   18224.0
# 4   강원특별자치도   소계  173762.0  143713.5  317475.5  166736.5  205557.0  372293.5
#
#          인구수                           소멸비율 소멸위기지역  id
# 구분        남자        여자         합계
# 0   102917.5  104956.5   207874.0  0.368465   True  강릉
# 1    13890.0   13189.5    27079.5  0.220891   True  고성
# 2    44582.5   43227.5    87810.0  0.333200   True  동해
# 3    31534.0   30499.5    62033.5  0.274610   True  삼척
# 4   762647.0  754712.5  1517359.5  0.386022   True  소계

# %%
popl_map = popl.set_index('id', inplace=True)

# %%
popl
# Out:
#        광역시도       시도     20-39세                             65세이상             \
# 구분                           남자         여자          합계         남자         여자
# id
# 강릉  강원특별자치도      강릉시    22929.0    19342.0     42271.0    22833.0    29660.5
# 고성  강원특별자치도      고성군     2829.0     1955.0      4784.0     3912.5     4938.0
# 동해  강원특별자치도      동해시     9370.5     7067.0     16437.5     9356.0    11853.5
# 삼척  강원특별자치도      삼척시     6306.0     5004.5     11310.5     7975.5    10248.5
# 소계  강원특별자치도       소계   173762.0   143713.5    317475.5   166736.5   205557.0
# 속초  강원특별자치도      속초시     9253.0     7392.5     16645.5     8208.5    10547.0
# 양구  강원특별자치도      양구군     2773.0     1815.5      4588.5     2462.5     2878.5
# 양양  강원특별자치도      양양군     2372.5     1709.5      4082.0     4306.5     5145.0
# 영월  강원특별자치도      영월군     2790.0     2215.5      5005.5     5971.0     6843.0
# 원주  강원특별자치도      원주시    45409.5    41556.5     86966.0    29435.5    36646.0
# ...

# %%
popl['소멸위기지역'].value_counts()
# Out:
# True     137
# False    110
# Name: 소멸위기지역, dtype: int64

# %%
popl['시도'].value_counts()
# Out:
# 소계         18
# 동구          6
# 중구          6
# 서구          5
# 북구          4
# 남구          4
# 고성군         2
# 강서구         2
# 남동구         1
# 연수구         1
# 부평구         1
# 미추홀구        1
# 강릉시         1
# 계양구         1
# 울주군         1
# 세종특별자치시     1
# 중랑구         1
# 종로구         1
# 강화군         1
# 옹진군         1
# 용산구         1
# 강진군         1
# 고흥군         1
# 곡성군         1
# 광양시         1
# 구례군         1
# 나주시         1
# 담양군         1
# 목포시         1
# 무안군         1
# 은평구         1
# 성북구         1
# 영등포구        1
# 양천구         1
# 영도구         1
# 해운대구        1
# 강남구         1
# 강동구         1
# 강북구         1
# 관악구         1
# 광진구         1
# 구로구         1
# 금천구         1
# 노원구         1
# 도봉구         1
# 동대문구        1
# 동작구         1
# 마포구         1
# 서대문구        1
# 서초구         1
# 성동구         1
# 순천시         1
# 송파구         1
# 보성군         1
# 신안군         1
# 수영구         1
# 계룡시         1
# 금산군         1
# 논산시         1
# 당진시         1
# 보령시         1
# 부여군         1
# ...

# %%
popl1 = popl[popl['시도'] != '소계']

# %%
popl1['시도'].value_counts()
# Out:
# 동구         6
# 중구         6
# 서구         5
# 남구         4
# 북구         4
# 강서구        2
# 고성군        2
# 세종특별자치시    1
# 울주군        1
# 계양구        1
# 중랑구        1
# 남동구        1
# 미추홀구       1
# 부평구        1
# 연수구        1
# 종로구        1
# 강화군        1
# 강릉시        1
# 용산구        1
# 옹진군        1
# 강진군        1
# 고흥군        1
# 곡성군        1
# 광양시        1
# 구례군        1
# 나주시        1
# 담양군        1
# 목포시        1
# 무안군        1
# 은평구        1
# 성북구        1
# 영등포구       1
# 양천구        1
# 영도구        1
# 해운대구       1
# 강남구        1
# 강동구        1
# 강북구        1
# 관악구        1
# 광진구        1
# 구로구        1
# 금천구        1
# 노원구        1
# 도봉구        1
# 동대문구       1
# 동작구        1
# 마포구        1
# 서대문구       1
# 서초구        1
# 성동구        1
# 순천시        1
# 송파구        1
# 보성군        1
# 신안군        1
# 수영구        1
# 계룡시        1
# 금산군        1
# 논산시        1
# 당진시        1
# 보령시        1
# 부여군        1
# 서산시        1
# 서천군        1
# 아산시        1
# 예산군        1
# 천안시        1
# ...

# %%
len(popl1[popl1['소멸위기지역']==True]) / len(popl1)
# Out:
# 0.5633187772925764

# %%
popl
# Out:
#        광역시도       시도     20-39세                             65세이상             \
# 구분                           남자         여자          합계         남자         여자
# id
# 강릉  강원특별자치도      강릉시    22929.0    19342.0     42271.0    22833.0    29660.5
# 고성  강원특별자치도      고성군     2829.0     1955.0      4784.0     3912.5     4938.0
# 동해  강원특별자치도      동해시     9370.5     7067.0     16437.5     9356.0    11853.5
# 삼척  강원특별자치도      삼척시     6306.0     5004.5     11310.5     7975.5    10248.5
# 소계  강원특별자치도       소계   173762.0   143713.5    317475.5   166736.5   205557.0
# 속초  강원특별자치도      속초시     9253.0     7392.5     16645.5     8208.5    10547.0
# 양구  강원특별자치도      양구군     2773.0     1815.5      4588.5     2462.5     2878.5
# 양양  강원특별자치도      양양군     2372.5     1709.5      4082.0     4306.5     5145.0
# 영월  강원특별자치도      영월군     2790.0     2215.5      5005.5     5971.0     6843.0
# 원주  강원특별자치도      원주시    45409.5    41556.5     86966.0    29435.5    36646.0
# ...

# %%
geo_path = 'C:/Users/USER/Desktop/연습데이터/WEEK03_01_공공데이터수집/data/05. skorea_municipalities_geo_simple.json'
geo_data = json.load(open('C:/Users/USER/Desktop/연습데이터/WEEK03_01_공공데이터수집/data/05. skorea_municipalities_geo_simple.json',encoding='utf-8'))

map2 = folium.Map(location=[36,127], zoom_start=7)

# %%
folium.Choropleth(geo_data=geo_data, 
               data=popl_map['인구수합계'],
               columns=[popl_map.index, popl_map['인구수합계']],
               key_on='feature.id',
               fill_color='YlGnBu').add_to(map2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [212], in <cell line: 1>()
#       1 folium.Choropleth(geo_data=geo_data,
# ----> 2                data=popl_map['인구수합계'],
#       3                columns=[popl_map.index, popl_map['인구수합계']],
#       4                key_on='feature.id',
#       5                fill_color='YlGnBu').add_to(map2)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
geo_data

# %%
map2

# %%
map2 = folium.Map(location=[36.2002, 127.054], zoom_start=7)
folium.Choropleth(geo_data=geo_data, 
               data=popl_map['소멸위기지역'],
               columns=[popl_map.index, popl_map['소멸위기지역']],
               key_on='feature.id',
               fill_color='PuRd').add_to(map2)
map2

# %%
popl.columns = popl.columns.get_level_values(0)
